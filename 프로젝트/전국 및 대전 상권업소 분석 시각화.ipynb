# %% [markdown]
# * 라이브러리 임포트

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 데이터 수집
# * 상가상권정보<br>
# https://www.data.go.kr/data/15083033/fileData.do

# %% [markdown]
# ## 데이터프레임 생성
# * 17개 파일의 데이터를 각각 데이터프레임으로 만든 후 합친다.

# %% [markdown]
# * column에 NaN값이나 여러 type의 데이터가 섞여 있으면 DtypeWarning 발생
# - 1.dtype option으로 타입을 명시하여 문자열 지정
# - 2.low_memory = False로 지정해 주어 메모리 최적화하지 않도록

# %%
df1 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_강원_202303.csv', dtype=str)

# %%
df2 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_경기_202303.csv', dtype=str)

# %%
df3 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_경남_202303.csv', dtype=str)

# %%
df4 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_경북_202303.csv', dtype=str, low_memory=False)

# %%
df5 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_광주_202303.csv', dtype=str, low_memory=False)

# %%
df6 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_대구_202303.csv', dtype=str, low_memory=False)

# %%
df7 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_대전_202303.csv', dtype=str, low_memory=False)

# %%
df8 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_부산_202303.csv', dtype=str, low_memory=False)

# %%
df9 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_서울_202303.csv', dtype=str, low_memory=False)

# %%
df10 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_세종_202303.csv', dtype=str, low_memory=False)

# %%
df11 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_울산_202303.csv', dtype=str, low_memory=False)

# %%
df12 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_인천_202303.csv', dtype=str, low_memory=False)

# %%
df13 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_전남_202303.csv', dtype=str, low_memory=False)

# %%
df14 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_전북_202303.csv', dtype=str, low_memory=False)

# %%
df15 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_제주_202303.csv', dtype=str, low_memory=False)

# %%
df16 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_충남_202303.csv', dtype=str, low_memory=False)

# %%
df17 = pd.read_csv('C:\python data\프로젝트\프로젝트 파일\소상공인 상권분석\소상공인시장진흥공단_상가(상권)정보_충북_202303.csv', dtype=str, low_memory=False)

# %% [markdown]
# ### 데이터프레임 연결

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17], ignore_index = True)

# %%
len(df.columns)
# Out:
# 39

# %%
# 컬럼갯수 최대 지정
pd.options.display.max_columns=39

# %%
df.head(1)
# Out:
#                  상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA0101202210A0084547  금강산노래광장  NaN        I2       음식      I211       주점
#
#   상권업종소분류코드  상권업종소분류명 표준산업분류코드    표준산업분류명 시도코드  시도명  시군구코드 시군구명     행정동코드  \
# 0    I21101  일반 유흥 주점   I56211  일반 유흥 주점업   42  강원도  42170  동해시  42170520
#
#   행정동명       법정동코드 법정동명                 지번코드 대지구분코드 대지구분명 지번본번지 지번부번지  \
# 0  송정동  4217010300  송정동  4217010300107470000      1    대지   747   NaN
#
#               지번주소         도로명코드          도로명 건물본번지 건물부번지  \
# 0  강원도 동해시 송정동 747  421703221039  강원도 동해시 송정로    11   NaN
#
#                       건물관리번호  건물명           도로명주소   구우편번호  신우편번호  동정보 층정보  \
# 0  4217010300007470000000086  파크장  강원도 동해시 송정로 11  240806  25789  NaN   지
#
#    호정보               경도                위도
# 0  NaN  129.12752511744  37.4952646683955

# %% [markdown]
# # 데이터 확인 및 전처리

# %% [markdown]
# ## 데이터 크기

# %%
df.shape
# Out:
# (2444338, 39)

# %% [markdown]
# ## 데이터프레임 정보

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2444338 entries, 0 to 2444337
# Data columns (total 39 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   상가업소번호     object
#  1   상호명        object
#  2   지점명        object
#  3   상권업종대분류코드  object
#  4   상권업종대분류명   object
#  5   상권업종중분류코드  object
#  6   상권업종중분류명   object
#  7   상권업종소분류코드  object
#  8   상권업종소분류명   object
#  9   표준산업분류코드   object
#  10  표준산업분류명    object
#  11  시도코드       object
#  12  시도명        object
#  13  시군구코드      object
#  14  시군구명       object
#  15  행정동코드      object
#  16  행정동명       object
#  17  법정동코드      object
#  18  법정동명       object
#  19  지번코드       object
#  20  대지구분코드     object
#  21  대지구분명      object
#  22  지번본번지      object
#  23  지번부번지      object
#  24  지번주소       object
#  25  도로명코드      object
#  26  도로명        object
#  27  건물본번지      object
#  28  건물부번지      object
#  29  건물관리번호     object
#  30  건물명        object
#  31  도로명주소      object
#  32  구우편번호      object
# ...

# %% [markdown]
# ## 서브셋 생성

# %%
df.head(1)
# Out:
#                  상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA0101202210A0084547  금강산노래광장  NaN        I2       음식      I211       주점
#
#   상권업종소분류코드  상권업종소분류명 표준산업분류코드    표준산업분류명 시도코드  시도명  시군구코드 시군구명     행정동코드  \
# 0    I21101  일반 유흥 주점   I56211  일반 유흥 주점업   42  강원도  42170  동해시  42170520
#
#   행정동명       법정동코드 법정동명                 지번코드 대지구분코드 대지구분명 지번본번지 지번부번지  \
# 0  송정동  4217010300  송정동  4217010300107470000      1    대지   747   NaN
#
#               지번주소         도로명코드          도로명 건물본번지 건물부번지  \
# 0  강원도 동해시 송정동 747  421703221039  강원도 동해시 송정로    11   NaN
#
#                       건물관리번호  건물명           도로명주소   구우편번호  신우편번호  동정보 층정보  \
# 0  4217010300007470000000086  파크장  강원도 동해시 송정로 11  240806  25789  NaN   지
#
#    호정보               경도                위도
# 0  NaN  129.12752511744  37.4952646683955

# %%
# 컬럼명 가져오기
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %% [markdown]
# ### 필요한 컬럼만 추출하여 서브셋 만들기
# * copy()기능을 사용

# %%
df_store = df[['상호명','상권업종대분류명','상권업종중분류명','상권업종소분류명','시도명','시군구명','행정동명','법정동명','경도','위도']].copy()

# %%
df_store
# Out:
#                   상호명 상권업종대분류명   상권업종중분류명  상권업종소분류명   시도명     시군구명  행정동명 법정동명  \
# 0             금강산노래광장       음식         주점  일반 유흥 주점   강원도      동해시   송정동  송정동
# 1        에이치속눈썹수강아카데미    수리·개인      이용·미용    피부 관리실   강원도      춘천시   동내면  동내면
# 2                  엔젤       음식         한식    백반/한정식   강원도      정선군    남면   남면
# 3                누베헤어    수리·개인      이용·미용       미용실   강원도      춘천시   강남동  삼천동
# 4                  공차       음식      비알코올         카페   강원도      원주시   지정면  지정면
# ...               ...      ...        ...       ...   ...      ...   ...  ...
# 2444333       입시·교과학원       교육      일반 교육   입시·교과학원  충청북도  청주시 흥덕구  강서1동  비하동
# 2444334     이마트24충북영동       소매      종합 소매       편의점  충청북도      영동군   영동읍  영동읍
# 2444335          백운산장       음식         한식    백반/한정식  충청북도      제천시   수산면  수산면
# 2444336      시투안강서위너스       소매  의약·화장품 소매   화장품 소매업  충청북도  청주시 흥덕구  강서1동  비하동
# 2444337          초연식당       음식         한식    백반/한정식  충청북도      제천시   봉양읍  봉양읍
#
# ...

# %% [markdown]
# ### 서브셋 데이터 확인

# %%
# 데이터 크기
df_store.shape
# Out:
# (2444338, 10)

# %%
# 데이터 정보(메모리 용량)
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2444338 entries, 0 to 2444337
# Data columns (total 10 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   상호명       object
#  1   상권업종대분류명  object
#  2   상권업종중분류명  object
#  3   상권업종소분류명  object
#  4   시도명       object
#  5   시군구명      object
#  6   행정동명      object
#  7   법정동명      object
#  8   경도        object
#  9   위도        object
# dtypes: object(10)
# memory usage: 186.5+ MB

# %% [markdown]
# ### 결측치분석/처리

# %%
df_store.isnull().sum()
# Out:
# 상호명         1
# 상권업종대분류명    0
# 상권업종중분류명    0
# 상권업종소분류명    0
# 시도명         0
# 시군구명        0
# 행정동명        0
# 법정동명        0
# 경도          0
# 위도          0
# dtype: int64

# %% [markdown]
# ## 상권업종분류

# %%
df_store['상권업종대분류명'].unique()
# Out:
# array(['음식', '수리·개인', '숙박', '시설관리·임대', '소매', '부동산', '과학·기술', '예술·스포츠',
#        '교육', '보건의료'], dtype=object)

# %%
df_store['상권업종대분류명'].nunique()
# Out:
# 10

# %%
df_store['상권업종중분류명'].unique()
# Out:
# array(['주점', '이용·미용', '한식', '비알코올 ', '일반 숙박', '기타 간이', '시설관리', '종합 소매',
#        '중식', '서양식', '부동산 서비스', '본사·경영 컨설팅', '유원지·오락', '전문 디자인', '산업용품 대여',
#        '연료 소매', '기타 사업 서비스', '회계·세무', '가전·통신 소매', '스포츠 서비스', '기타 상품 소매',
#        '오락용품 소매', '의약·화장품 소매', '중고 상품 소매', '식료품 소매', '섬유·의복·신발 소매',
#        '청소·방제', '광고', '모터사이클 소매', '기타 교육', '가구 소매', '자동차 수리·세차', '기술 서비스',
#        '구내식당·뷔페', '음료 소매', '일반 교육', '식물 소매', '운송장비 대여', '세탁', '교육 지원',
#        '안경·정밀기기 소매', '기타 가정용품 수리', '고용 알선', '사진 촬영', '의원', '기타 생활용품 소매',
#        '욕탕·신체관리', '가전제품 수리', '장식품 소매', '법무관련 ', '가정용품 대여', '장례식장 ', '병원',
#        '애완동물·용품 소매', '일식', '철물·건설자재 소매', '인쇄·제품제작', '조경·유지', '시장 조사',
#        '도서관·사적지', '동남아시아', '통신장비 수리', '시계·귀금속 소매', '수의', '기타 숙박',
#        '기타 전문 과학', '컴퓨터 수리', '자동차 부품 소매', '여행사·보조', '모터사이클 수리', '기타 개인',
#        '사무 지원', '담배 소매', '기타 보건', '기타 외국'], dtype=object)

# %%
df_store['상권업종중분류명'].nunique()
# Out:
# 75

# %%
df_store['상권업종소분류명'].nunique()
# Out:
# 247

# %% [markdown]
# ### 상권업종분류표

# %%
df_store_class = df_store[['상권업종대분류명','상권업종중분류명','상권업종소분류명']].drop_duplicates().sort_values(['상권업종대분류명','상권업종중분류명','상권업종소분류명'])

# %%
# 상권업종 분류표 (최대 행 수 지정)
pd.options.display.max_rows=20
df_store_class
# Out:
#       상권업종대분류명 상권업종중분류명       상권업종소분류명
# 165      과학·기술       광고         광고 대행업
# 41946    과학·기술       광고      광고 매체 판매업
# 1536     과학·기술       광고     광고물 설계/제작업
# 2579     과학·기술       광고  기타 광고 관련 서비스업
# 68       과학·기술       광고   옥외/전시 광고 대행업
# ...        ...      ...            ...
# 86          음식       한식       소고기 구이/찜
# 659         음식       한식          전/부침개
# 193         음식       한식          족발/보쌈
# 66          음식       한식       해산물 구이/찜
# 99          음식       한식             횟집
#
# [247 rows x 3 columns]

# %% [markdown]
# # 전국 상가 등록 현황

# %% [markdown]
# ## 업종 대분류별 상가 갯수

# %%
df_store_class1 = df_store['상권업종대분류명'].value_counts()
df_store_class1
# Out:
# 음식         781872
# 소매         617719
# 수리·개인      297081
# 과학·기술      238604
# 부동산        114889
# 예술·스포츠     109993
# 교육         103577
# 시설관리·임대     93724
# 숙박          63203
# 보건의료        23676
# Name: 상권업종대분류명, dtype: int64

# %%
fig = plt.figure(figsize=(10,5), facecolor='snow')

# 막대그래프
plt.subplot(121)
plt.bar(df_store_class1.index, df_store_class1.values)
plt.xticks(rotation=45)
plt.grid(axis='y',ls=':')

# 파이그래프
plt.subplot(122)
plt.pie(df_store_class1.values, labels=df_store_class1.index, autopct='%.1f%%', pctdistance=0.8,
       wedgeprops={'width':0.6})

fig.suptitle('전국 업종별 상가 등록 현황', size=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 시도별 상가 갯수

# %%
df_store_sido = df_store['시도명'].value_counts()
df_store_sido
# Out:
# 경기도        554709
# 서울특별시      474260
# 경상남도       163973
# 부산광역시      149567
# 경상북도       136508
# 인천광역시      112343
# 대구광역시      111472
# 충청남도       109203
# 강원도         95503
# 전라남도        95336
# 전라북도        92654
# 충청북도        83556
# 광주광역시       72846
# 대전광역시       72500
# 제주특별자치도     53917
# 울산광역시       52301
# 세종특별자치시     13690
# Name: 시도명, dtype: int64

# %%
fig = plt.figure(figsize=(10,5), facecolor='snow')

# 막대그래프
plt.subplot(121)
plt.bar(df_store_sido.index, df_store_sido.values)
plt.xticks(rotation=45)
plt.grid(axis='y',ls=':')

# 파이그래프
plt.subplot(122)
plt.pie(df_store_sido.values, labels=df_store_sido.index, autopct='%.1f%%', pctdistance=0.8,
       wedgeprops={'width':0.6})

fig.suptitle('전국 시도별 상가 등록 현황', size=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 시도별 업종대분류별 상가 현황

# %%
df_store_pivot = df_store.pivot_table(index='상권업종대분류명', columns='시도명', values='상호명', aggfunc='count')

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df_store_pivot, cmap='Blues', annot=True, fmt='d')
plt.show()

# %% [markdown]
# # 대전광역시 상가 현황

# %%
df_store_Daejeon = df_store[df_store['시도명']=='대전광역시'].copy()
df_store_Daejeon.head(3)
# Out:
#            상호명 상권업종대분류명  상권업종중분류명    상권업종소분류명    시도명 시군구명  행정동명 법정동명  \
# 1135011   줄또웰빙       소매    식료품 소매  건강보조식품 소매업  대전광역시   동구   용전동  용전동
# 1135012  개성칼국수       음식        한식      국수/칼국수  대전광역시   중구    목동   목동
# 1135013   엘모바일       소매  가전·통신 소매     핸드폰 소매업  대전광역시   서구  둔산2동  둔산동
#
#                        경도                위도
# 1135011  127.432704336866  36.3480905603285
# 1135012  127.411318737377  36.3355768948911
# 1135013  127.376345852427  36.3532262391251

# %% [markdown]
# ## 구별 상가 등록 현황

# %%
df_store_Daejeon_gu = df_store_Daejeon['시군구명'].value_counts()
df_store_Daejeon_gu
# Out:
# 서구     24131
# 유성구    17396
# 중구     12187
# 동구     10599
# 대덕구     8187
# Name: 시군구명, dtype: int64

# %% [markdown]
# ## 판다스 함수로 시각화
# * 데이터프레임.plot.함수명

# %%
df_store_Daejeon_gu
# Out:
# 서구     24131
# 유성구    17396
# 중구     12187
# 동구     10599
# 대덕구     8187
# Name: 시군구명, dtype: int64

# %%
fig = plt.figure(figsize=(10,5))

plt.subplot(121)
#df_store_Daejeon_gu.plot(kind='bar')
df_store_Daejeon_gu.plot.bar(color='r')

plt.subplot(122)
df_store_Daejeon_gu.plot.pie(autopct='%.1f%%', pctdistance=0.8, wedgeprops={'width':0.6})

fig.suptitle('대전광역시 구별 상가등록 현황', size=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 구별/업종대분류별 상가 현황

# %% [markdown]
# ### 히트맵으로 시각화

# %%
df_store_Daejeon_pivot = df_store_Daejeon.pivot_table(index='상권업종대분류명' , columns='시군구명', values='상호명', aggfunc='count')

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df_store_Daejeon_pivot, cmap='Purples', annot=True, fmt='d')
plt.show()
