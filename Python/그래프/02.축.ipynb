# %% [markdown]
# # 축

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun gothic'  #한글폰트 설정해야함
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 - 깨지는 현상 해결

# %%
x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프', fontdict={'family':'HYGungSo-Bold', 'size':20})
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot(x, y)
plt.xlabel('x축')
plt.ylabel('y축')
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x, y)
plt.xlabel('x축', color='r', loc='right') # left, center, right
plt.ylabel('y축', color='g', loc='top') #top, center, bottom
# Out:
# Text(0, 1, 'y축')

# %%
plt.plot(x, y)                  #그래프 범위 설정
plt.xticks([1,2,3])
plt.yticks([3,9,10])
plt.show()
