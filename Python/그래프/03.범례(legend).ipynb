# %% [markdown]
# # 범례(legend)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun gothic'  #한글폰트 설정해야함
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 - 깨지는 현상 해결

# %%
x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt.plot(x,y, label= "데이터??")
plt.legend()

# %%
plt.plot(x,y, label= "데이터??")
plt.legend(loc='upper right')

# %%
plt.plot(x,y, label= "데이터??")
plt.legend(loc='lower right')

# %%
plt.plot(x,y, label= "범례")
plt.legend(loc=(0.8,0.7)) # x,y축 [0~1]사이 범위설정

# %%
plt.figure(figsize=(5, 10))
plt.plot(x,y)

# %%
plt.figure(figsize=(10, 5), dpi=49) # 인치당 도트 수
plt.plot(x,y)

# %% [markdown]
# # 그래프 배경색

# %%
plt.figure(facecolor='yellow')
plt.plot(x,y)
